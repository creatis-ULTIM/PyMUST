# %%
import numpy as np
import pymust # To install it, use pip -e . install, orcopy the src/pymust folder to your project
import pymust.utils
import matplotlib.pyplot as plt
import scipy, scipy.io
import matplotlib, tqdm, tqdm.notebook, time
import sklearn

# %%
from line_profiler import LineProfiler
debug_line = False

# %% [markdown]
# # Test disk
# Here I generate a rotating disk, I test simus, txdelay, dasmtx, rf2iq and bmode

# %%
def rotatePoints(x, y, x0, y0, theta):
    """
    Rotate points (x,y) around (x0,y0) by theta radians
    """
    x = x - x0
    y = y - y0
    x1 = x * np.cos(theta) - y * np.sin(theta) + x0
    y1 = x * np.sin(theta) + y * np.cos(theta) + y0
    return x1, y1

# %%
param = pymust.getparam('P4-2v')
if debug_line:
    nPoints = 50000
else:
    nPoints = 200000
xs = np.random.rand(1,nPoints)*12e-2-6e-2
zs = np.random.rand(1,nPoints)*12e-2

centerDisk = 0.05
idx = np.hypot(xs,zs-centerDisk)<2e-2 # First disk
idx2 = np.hypot(xs,zs-.035)< 5e-3 # Second disk

RC = np.random.rand(*xs.shape)  # reflection coefficients

# Add reflectiion to both spheres
RC[idx] += 1
RC[idx2] += 2


# Rotating disk velocity
rotation_frequency = .5
w = 2 * np.pi  * rotation_frequency#1 Hz = 2 pi rads
nreps = 5
param.PRP = 1e-3

# %%
options = pymust.utils.Options()
options.ParPoolMode = 'process'
options.ParPool_NumWorkers = 12
options.dBThresh = -6
options.ParPool = False

width = 60/180*np.pi; # width angle in rad
txdel = pymust.txdelay(param,0,width) # in s
RF, RF_spectrum = pymust.simus(xs,zs,RC,txdel,param, options)
IQ = pymust.rf2iq(RF,param)


b = pymust.bmode(IQ[:,:,0])
fig = plt.figure(figsize=[5,5])
ax = fig.add_axes([0.15,0.15,0.8,0.8])
#fig.set_facecolor("black")
ax.pcolormesh(z, x , b,edgecolors='face', cmap = 'gray')
ax.set_facecolor('black')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 13
#       9 RF, RF_spectrum = pymust.simus(xs,zs,RC,txdel,param, options)
#      10 IQ = pymust.rf2iq(RF,param)
# ---> 13 b = pymust.bmode(IQ[:,:,0])
#      14 fig = plt.figure(figsize=[5,5])
#      15 ax = fig.add_axes([0.15,0.15,0.8,0.8])
#
# IndexError: too many indices for array: array is 2-dimensional, but 3 were indexed

# %%
if debug_line:
    lp = LineProfiler()
    lp.add_function(pymust.pfield)
    pymust.simus = lp(pymust.simus)

# %%
t = time.time()
for i in tqdm.tqdm(range(nreps)):
    options = pymust.utils.Options()
    options.ParPoolMode = 'process'
    options.ParPool_NumWorkers = 12
    options.dBThresh = -6
    options.ParPool = True and not debug_line

    xs[idx], zs[idx] = rotatePoints(xs[idx], zs[idx], 0, centerDisk,  w *  param.PRP)
    width = 60/180*np.pi; # width angle in rad
    txdel = pymust.txdelay(param,0,width) # in s
    RF, RF_spectrum = pymust.simus(xs,zs,RC,txdel,param, options)
    if i ==0:
        IQ = np.zeros([RF.shape[0], RF.shape[1], nreps], dtype = np.complex128)
    IQ[:, :, i] = pymust.rf2iq(RF,param)
print('elapsed time = ', time.time() - t)
# Out:
# 100%|██████████| 5/5 [00:12<00:00,  2.51s/it]
# elapsed time =  12.546819925308228

# %%
help(lp.print_stats)
# Out:
# Help on method print_stats in module line_profiler.line_profiler:
#
# print_stats(stream=None, output_unit=None, stripzeros=False) method of line_profiler.line_profiler.LineProfiler instance
#     Show the gathered statistics.

# %%
if debug_line:
    lp.print_stats(output_unit = 1)
    lp.dump_stats('rotatingDiskVelocitySynthetic.lprof')
# Out:
# Timer unit: 1 s
#
# Total time: 12.3838 s
# File: /Users/gbernardino/pymust/src/pymust/pfield.py
# Function: pfield at line 9
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      9                                           def pfield(x : np.ndarray,y : np.ndarray, z: np.ndarray, delaysTX : np.ndarray, param: utils.Param, isQuick : bool = False, options : utils.Options = None):
#     10                                           #PFIELD   RMS acoustic pressure field of a linear or convex array
#     11                                           #   RP = PFIELD(X,Y,Z,DELAYS,PARAM) returns the radiation pattern of a
#     12                                           #   uniform LINEAR or CONVEX array whose elements are excited at different
#     13                                           #   time delays (given by the vector DELAYS). The radiation pattern RP is
#     14                                           #   given in terms of the root-mean-square (RMS) of acoustic pressure. The
#     15                                           #   characteristics of the array and transmission must be given in the
#     16                                           #   structure PARAM (see below for details). The radiation pattern is
#     17                                           #   calculated at the points specified by (X,Y,Z).
#     18                                           #
#     19                                           #   RP = PFIELD(X,Z,DELAYS,PARAM) or RP = PFIELD(X,[],Z,DELAYS,PARAM)
#     20                                           #   disregards elevation focusing (PARAM.focus is ignored) and assumes that
#     21                                           #   Y=0 (2-D space). The computation is faster in 2-D.
#     22                                           #
#     23                                           #   >--- Try it: enter "pfield" in the command window for an example ---<
#     24                                           #
#     25                                           #   Units: X,Y,Z must be in m; DELAYS must be in s.
#     26                                           #
#     27                                           #   DELAYS can be a matrix. This syntax can be used to simulate MLT
#     28                                           #   (multi-line transmit) sequences. In this case, each ROW represents a
#     29                                           #   delay series. For example, to create a 4-MLT sequence with a 64-element
#     30                                           #   phased array, the DELAYS matrix must have 4 rows and 64 columns (size =
#     31                                           #   [4 64]).
#     32                                           #
#     33                                           #   PFIELD is called by SIMUS to simulate ultrasound RF radio-frequency
#     34                                           #   signals generated by an ultrasound uniform linear or convex array.
#     35                                           #
#     36                                           #   ---
#     37                                           #   NOTE #1: X-, Y-, and Z-axes
#     38                                           #   Conventional axes are used:
#     39                                           #   i)  For a LINEAR array, the X-axis is PARALLEL to the transducer and
#     40                                           #       points from the first (leftmost) element to the last (rightmost)
#     41                                           #       element (X = 0 at the CENTER of the transducer). The Z-axis is
#     42                                           #       PERPENDICULAR to the transducer and points downward (Z = 0 at the
#     43                                           #       level of the transducer, Z increases as depth increases). The
#     44                                           #       Y-axis is such that the coordinates are right-handed.
#     45                                           #   ii) For a CONVEX array, the X-axis is parallel to the chord and Z = 0
#     46                                           #       at the level of the chord.
#     47                                           #   ---
#     48                                           #   NOTE #2: Simplified method: Directivity
#     49                                           #   By default, the calculation is made faster by assuming that the
#     50                                           #   directivity of the elements is dependent only on the central frequency.
#     51                                           #   This simplification very little affects the pressure field in most
#     52                                           #   situations (except near the array). To turn off this option, use
#     53                                           #   OPTIONS.FullFrequencyDirectivity = true.
#     54                                           #   (see ADVANCED OPTIONS below).
#     55                                           #   ---
#     56                                           #
#     57                                           #   PARAM is a structure that contains the following fields:
#     58                                           #   -------------------------------------------------------
#     59                                           #       *** TRANSDUCER PROPERTIES ***
#     60                                           #   1)  PARAM.fc: central frequency (in Hz, REQUIRED)
#     61                                           #   2)  PARAM.pitch: pitch of the array (in m, REQUIRED)
#     62                                           #   3)  PARAM.width: element width (in m, REQUIRED)
#     63                                           #        or PARAM.kerf: kerf width (in m, REQUIRED)
#     64                                           #        note: width = pitch-kerf
#     65                                           #   4)  PARAM.focus: elevation focus (in m, ignored if Y is not given)
#     66                                           #            The default is Inf (no elevation focusing)
#     67                                           #   5)  PARAM.height: element height (in m, ignored if Y is not given)
#     68                                           #            The default is Inf (no elevation focusing)
#     69                                           #   6)  PARAM.radius: radius of curvature of the probe (in m)
#     70                                           #            The default is Inf (rectilinear array)
#     71                                           #   7)  PARAM.bandwidth: pulse-echo 6dB fractional bandwidth (in %)
#     72                                           #            The default is 75%.
#     73                                           #   8)  PARAM.baffle: property of the baffle:
#     74                                           #            'soft' (default), 'rigid', or a scalar > 0.
#     75                                           #            See "Note on BAFFLE properties" below for details
#     76                                           #
#     77                                           #       *** MEDIUM PARAMETERS ***
#     78                                           #   9)  PARAM.c: longitudinal velocity (in m/s, default = 1540 m/s)
#     79                                           #   10) PARAM.attenuation: attenuation coefficient (dB/cm/MHz, default: 0)
#     80                                           #            Notes: A linear frequency-dependence is assumed.
#     81                                           #                   A typical value for soft tissues is ~0.5 dB/cm/MHz.
#     82                                           #
#     83                                           #       *** TRANSMIT PARAMETERS ***
#     84                                           #   11) PARAM.TXapodization: transmit apodization (default: no apodization)
#     85                                           #   12) PARAM.TXnow: number of wavelengths of the TX pulse (default: 1)
#     86                                           #   13) PARAM.TXfreqsweep: frequency sweep for a linear chirp (default: [])
#     87                                           #                          To be used to simulate a linear TX chirp.
#     88                                           #
#     89                                           #   Other syntaxes:
#     90                                           #   --------------
#     91                                           #   i}  [RP,PARAM] = PFIELD(...) also returns the complete list of
#     92                                           #       parameters including the default values.
#     93                                           #   ii} [...] = PFIELD without any input argument provides an interactive
#     94                                           #       example designed to produce a focused ultrasound beam using a 2.7
#     95                                           #       MHz phased-array transducer (without elevation focusing).
#     96                                           #
#     97                                           #
#     98                                           #   Note on CHIRP signals:
#     99                                           #   ---------------------
#    100                                           #   Linear chirps are characterized by PARAM.TXnow, PARAM.fc and
#    101                                           #   PARAM.TXfreqsweep. The transmitted pulse The transmitted pulse has a
#    102                                           #   duration of approximately T (= PARAM.TXnow/PARAM.fc), with the
#    103                                           #   amplitude and phase defined over the time interval -T/2 to +T/2. The
#    104                                           #   total frequency sweep is DeltaF (= PARAM.TXfreqsweep): the frequencies
#    105                                           #   changes linearly from (PARAM.fc - DeltaF/2) to (PARAM.fc + DeltaF/2)
#    106                                           #   in the defined time interval.
#    107                                           #
#    108                                           #
#    109                                           #   Note on BAFFLE property:
#    110                                           #   -----------------------
#    111                                           #   In PFIELD, it is assumed by default that the array elements are
#    112                                           #   embedded in an infinite SOFT baffle. To modify the property of the
#    113                                           #   baffle, modify the field PARAM.baffle:
#    114                                           #       1) 'rigid'
#    115                                           #       2) 'soft' (this is the default)
#    116                                           #       3) a nonnegative scalar Alpha,
#    117                                           #          with Alpha = (medium impedance)/(baffle impedance)
#    118                                           #          Note: Alpha = 0 => 'rigid'; Alpha >> 1 => 'soft'
#    119                                           #
#    120                                           #   The baffle property affects the obliquity factor included in the
#    121                                           #   directivity of the elements. This obliquity factor is not 1 if the
#    122                                           #   baffle is not rigid. A general case (see case #3 below) can be chosen
#    123                                           #   by specifying an impedance ratio. For details, refer to the
#    124                                           #   corresponding papers.
#    125                                           #   1) For a rigid baffle => obliquity factor = 1.
#    126                                           #   2) For a soft baffle => obliquity factor = cos(Theta).
#    127                                           #      Selfridge et al. Appl Phys Lett 37(1), 35-36 (1980)
#    128                                           #      "A theory for the radiation pattern of a narrow-strip acoustic
#    129                                           #      transducer." <a
#    130                                           #      href="matlab:web('http://scitation.aip.org/content/aip/journal/apl/37/1/10.1063/1.91692')">Paper here</a>
#    131                                           #   3) General baffle => obliquity factor = cos(Theta)/(cos(Theta)+Alpha)
#    132                                           #      with Alpha = (medium impedance)/(baffle impedance).
#    133                                           #      Pesqu� et al. IEEE Ultrasonics Symposium, (1984)
#    134                                           #      "Effect of the planar baffle impedance in acoustic radiation of a
#    135                                           #      phased array element theory and experimentation." <a
#    136                                           #      href="matlab:web('http://ieeexplore.ieee.org/xpl/articleDetails.jsp?arnumber=1535402')">Paper here</a>
#    137                                           #      Example: For a baffle of impedance 2.8 MRayl (epoxy) adjacent to
#    138                                           #               soft tissues of impedance 1.6 MRayls, alpha = 1.75.
#    139                                           #
#    140                                           #
#    141                                           #   ADVANCED OPTIONS:
#    142                                           #   ----------------
#    143                                           #       %-- FREQUENCY SAMPLES --%
#    144                                           #   1)  Only frequency components of the transmitted signal in the range
#    145                                           #       [0,2fc] with significant amplitude are considered. The default
#    146                                           #       relative amplitude is -60 dB in PFIELD. You can change this value
#    147                                           #       by using the following:
#    148                                           #           [...] = PFIELD(...,OPTIONS),
#    149                                           #       where OPTIONS.dBThresh is the threshold in dB (default = -60).
#    150                                           #   ---
#    151                                           #       %-- FULL-FREQUENCY DIRECTIVITY --%
#    152                                           #   2)  By default, the directivity of the elements depends on the center
#    153                                           #       frequency only. This makes the algorithm faster. To make the
#    154                                           #       directivities fully frequency-dependent, use:
#    155                                           #           [...] = PFIELD(...,OPTIONS),
#    156                                           #       with OPTIONS.FullFrequencyDirectivity = true (default = false).
#    157                                           #   ---
#    158                                           #       %-- ELEMENT SPLITTING --%
#    159                                           #   3)  Each transducer element of the array is split into small segments.
#    160                                           #       The length of these small segments must be small enough to ensure
#    161                                           #       that the far-field model is accurate. By default, the elements are
#    162                                           #       split into M segments, with M being defined by:
#    163                                           #           M = ceil(element_width/smallest_wavelength);
#    164                                           #       To modify the number M of subelements by splitting, you may adjust
#    165                                           #       OPTIONS.ElementSplitting. For example, OPTIONS.ElementSplitting = 1
#    166                                           #   ---
#    167                                           #       %-- WAIT BAR --%
#    168                                           #   4)  If OPTIONS.WaitBar is true, a wait bar appears (only if the number
#    169                                           #       of frequency samples >10). Default is true.
#    170                                           #   ---
#    171                                           #
#    172                                           #
#    173                                           #   Notes regarding the model & REFERENCES:
#    174                                           #   --------------------------------------
#    175                                           #   1) PFIELD works for uniform linear or convex arrays. A uniform array
#    176                                           #      has identical elements along a rectilinear or curved line in space
#    177                                           #      with uniform spacing. Each element is split into small segments (if
#    178                                           #      required). The radiation patterns in the x-z plane are derived by
#    179                                           #      using Fraunhofer (far-field) equations. Those in the x-y elevational
#    180                                           #      plane are derived by using a Fresnel (paraxial) approximation.
#    181                                           #   2) The paper that describes the first 2-D version of PFIELD is:
#    182                                           #      SHAHRIARI S, GARCIA D. Meshfree simulations of ultrasound vector
#    183                                           #      flow imaging using smoothed particle hydrodynamics. Phys Med Biol,
#    184                                           #      2018;63:205011. <a
#    185                                           #      href="matlab:web('https://www.biomecardio.com/publis/physmedbio18.pdf')">PDF here</a>
#    186                                           #   3) The paper that describes the theory of the full (2-D + 3-D) version
#    187                                           #      of PFIELD is under review.
#    188                                           #
#    189
#    190         5          0.0      0.0      0.0      if x is None or (isinstance(x, list) and len(x) == 0):
#    191                                                   x =  np.array([])
#    192         5          0.0      0.0      0.0      if y is None or (isinstance(y, list) and len(y) == 0):
#    193         5          0.0      0.0      0.0          y =  np.array([])
#    194         5          0.0      0.0      0.0      if z is None or (isinstance(z, list) and len(z) == 0):
#    195                                                   z =  np.array([])
#    196
#    197         5          0.0      0.0      0.0      if options is None:
#    198         5          0.0      0.0      0.0          if isinstance(isQuick, utils.Options):
#    199         5          0.0      0.0      0.0              options = isQuick
#    200         5          0.0      0.0      0.0              isQuick = False
#    201                                                   else:
#    202                                                       options = utils.Options()
#    203
#    204         5          0.0      0.0      0.0      if isQuick:
#    205                                                   options.dBThresh = -20
#    206                                                   options.ElementSplitting = 1
#    207                                                   options.FullFrequencyDirectivity = False
#    208                                                   options.FrequencyStep = 1.5
#    209
#    210         5          0.0      0.0      0.0      if y is None or len(y) == 0:
#    211         5          0.0      0.0      0.0          ElevationFocusing = False
#    212         5          0.0      0.0      0.0          assert np.array_equal(x.shape, z.shape), 'X and Z must be of same size.'
#    213         5          0.0      0.0      0.0          y = np.zeros(x.shape, dtype = np.float32)
#    214                                               else:
#    215                                                   ElevationFocusing = True
#    216                                                   assert x.shape == y.shape and y.shape == z.shape, 'X, Y, and Z must be of same size.'
#    217
#    218                                               #
#    219                                               #assert len(delaysTX.shape) == 2., 'G. Bernardino: DELAYS must be a single row array. Multiline transmit still not  implemented in Python.'
#    220
#    221                                               #Check the transmit delays
#    222         5          0.0      0.0      0.0      assert utils.isnumeric(delaysTX) and all(delaysTX[~np.isnan(delaysTX)]>=0),  'DELAYS must be a nonnegative array.'
#    223
#    224         5          0.0      0.0      0.0      NumberOfElements = delaysTX.shape[1]
#    225                                               # Note: param.Nelements can be required in other functions of the
#    226                                               #       Matlab Ultrasound Toolbox
#    227         5          0.0      0.0      0.0      if 'Nelements' in param:
#    228         5          0.0      0.0      0.0          assert param.Nelements==NumberOfElements, 'DELAYS must be of length PARAM.Nelements.'
#    229         5          0.0      0.0      0.0      param.Nelements = NumberOfElements
#    230
#    231
#    232                                               # Note: delaysTX can be a matrix. This option can be used for MLT
#    233                                               # (multi-line transmit) for example. In this case, each row represents a
#    234                                               # delay series. For example, for a 4-MLT sequence with a 64-element phased
#    235                                               # array, delaysTX has 4 rows and 64 columns, i.e. size(delaysTX) = [4 64].
#    236
#    237                                               #delaysTX  should be a row vector
#    238         5          0.0      0.0      0.0      if len(delaysTX.shape) == 1:
#    239                                                   delaysTX = delaysTX.reshape((1, -1))
#    240         5          0.0      0.0      0.0      delaysTX = delaysTX.astype(np.float32)
#    241                                               # Check if PFIELD is called by SIMUS or MKMOVIE
#    242         5          0.0      0.0      0.0      isSIMUS = False
#    243         5          0.0      0.0      0.0      isMKMOVIE = False
#    244         5          0.0      0.0      0.0      if 'CallFun' in options:
#    245         5          0.0      0.0      0.0          isSIMUS = options.CallFun == 'simus'
#    246         5          0.0      0.0      0.0          isMKMOVIE = options.CallFun == 'mkmovie'
#    247
#    248                                               #GB: TODO: do parallelism
#    249                                               #GB TODO:  For txhe moment no statistics.
#    250
#    251
#    252                                               #%---------------------------%
#    253                                               #% Check the PARAM structure %
#    254                                               #%---------------------------%
#    255
#    256         5          0.0      0.0      0.0      param = param.ignoreCaseInFieldNames()
#    257
#    258                                               #-- 1) Center frequency (in Hz)
#    259         5          0.0      0.0      0.0      assert 'fc' in param, 'A center frequency value (PARAM.fc) is required.'
#    260         5          0.0      0.0      0.0      fc = param.fc # central frequency (Hz)
#    261
#    262                                               #%-- 2) Pitch (in m)
#    263         5          0.0      0.0      0.0      assert'pitch' in param,'A pitch value (PARAM.pitch) is required.'
#    264         5          0.0      0.0      0.0      pitch = param.pitch
#    265
#    266                                               #%-- 3) Element width and/or Kerf width (in m)
#    267         5          0.0      0.0      0.0      if 'width' in param and 'kerf' in param:
#    268         5          0.0      0.0      0.0          assert np.abs(pitch-param.width-param.kerf)<utils.eps('single'), 'The pitch must be equal to (kerf width + element width).'
#    269                                               elif 'kerf' in param:
#    270                                                   param.width = pitch-param.kerf
#    271                                               elif 'width' in param:
#    272                                                   param.kerf = pitch-param.width
#    273                                               else:
#    274                                                   raise ValueError('An element width (PARAM.width) or kerf width (PARAM.kerf) is required.')
#    275         5          0.0      0.0      0.0      ElementWidth = param.width
#    276
#    277                                               #%-- 4) Elevation focus (in m)
#    278         5          0.0      0.0      0.0      if 'focus' not in param:
#    279                                                   param.focus = np.inf # default = no elevation focusing
#    280
#    281         5          0.0      0.0      0.0      Rf = param.focus
#    282         5          0.0      0.0      0.0      assert utils.isnumeric(Rf) and np.isscalar(Rf) and Rf>0, 'The element focus must be positive.'
#    283
#    284                                               #%-- 5) Element height (in m)
#    285         5          0.0      0.0      0.0      if  'height' not in param:
#    286                                                   param.height = np.inf # default = line array
#    287
#    288         5          0.0      0.0      0.0      ElementHeight = param.height
#    289         5          0.0      0.0      0.0      assert utils.isnumeric(ElementHeight) and np.isscalar(ElementHeight) and ElementHeight>0,'The element height must be positive.'
#    290
#    291                                               #%-- 6) Radius of curvature (in m) - convex array
#    292         5          0.0      0.0      0.0      if 'radius' not in param:
#    293                                                   param.radius = np.inf # default = linear array
#    294
#    295         5          0.0      0.0      0.0      RadiusOfCurvature = param.radius
#    296         5          0.0      0.0      0.0      assert utils.isnumeric(RadiusOfCurvature) and np.isscalar(RadiusOfCurvature) and RadiusOfCurvature>0,'The radius of curvature must be positive.'
#    297
#    298                                               #%-- 7) Fractional bandwidth at -6dB (in %)
#    299         5          0.0      0.0      0.0      if 'bandwidth' not in param:
#    300                                                   param.bandwidth = 75
#    301
#    302         5          0.0      0.0      0.0      assert param.bandwidth>0 and param.bandwidth<200, 'The fractional bandwidth at -6 dB (PARAM.bandwidth, in %) must be in ]0,200['
#    303
#    304                                               #%-- 8) Baffle
#    305                                               #   An obliquity factor will be used if the baffle is not rigid
#    306                                               #%   (default = SOFT baffle)
#    307         4          0.0      0.0      0.0      if  'baffle' not in param:
#    308         1          0.0      0.0      0.0          param.baffle = 'soft' #  default
#    309
#    310         5          0.0      0.0      0.0      if param.baffle == 'rigid':
#    311                                                   NonRigidBaffle = False
#    312         5          0.0      0.0      0.0      elif param.baffle == 'soft':
#    313         5          0.0      0.0      0.0          NonRigidBaffle = True
#    314                                               elif np.isscalar(param.baffle):
#    315                                                   assert param.baffle>0, 'The ''baffle'' field scalar must be positive'
#    316                                                   NonRigidBaffle = True
#    317                                               else:
#    318                                                   raise ValueError('The ''baffle'' field must be ''rigid'',''soft'' or a positive scalar')
#    319
#    320                                               #%-- 9) Longitudinal velocity (in m/s)
#    321         5          0.0      0.0      0.0      if  'c' not in param:
#    322                                                   param.c = 1540 # % default value
#    323
#    324         5          0.0      0.0      0.0      c = param.c  # speed of sound (m/s)
#    325
#    326                                               #%-- 10) Attenuation coefficient (in dB/cm/MHz)
#    327         4          0.0      0.0      0.0      if  'attenuation' not in param:  #no attenuation, alpha_dB = 0
#    328         1          0.0      0.0      0.0          param.attenuation = 0
#    329         1          0.0      0.0      0.0          alpha_dB = 0
#    330                                               else:
#    331         4          0.0      0.0      0.0          alpha_dB = param.attenuation
#    332         4          0.0      0.0      0.0          assert np.isscalar(alpha_dB) and utils.isnumeric(alpha_dB) and alpha_dB>=0, 'PARAM.attenuation must be a nonnegative scalar'
#    333
#    334
#    335                                               #%-- 11) Transmit apodization (no unit)
#    336         4          0.0      0.0      0.0      if  'TXapodization' not in param:
#    337         1          0.0      0.0      0.0          param.TXapodization = np.ones((1,NumberOfElements), dtype = np.float32)
#    338                                               else:
#    339         4          0.0      0.0      0.0          if isinstance(param.TXapodization, np.ndarray) and len(param.TXapodization.shape) == 1:
#    340                                                       param.TXapodization = param.TXapodization.reshape((1, -1))
#    341         4          0.0      0.0      0.0          assert (len(param.TXapodization.shape) == 2 and param.TXapodization.shape[0] == 1) and utils.isnumeric(param.TXapodization), 'PARAM.TXapodization must be a vector'
#    342         4          0.0      0.0      0.0          assert param.TXapodization.shape[1]==NumberOfElements, 'PARAM.TXapodization must be of length = (number of elements)'
#    343
#    344                                               #% apodization is 0 where TX delays are NaN:
#    345         5          0.0      0.0      0.0      idx = np.isnan(delaysTX)
#    346         5          0.0      0.0      0.0      param.TXapodization[0, np.any(idx, axis = 0)]= 0
#    347         5          0.0      0.0      0.0      delaysTX[idx] = 0
#    348
#    349                                               # 12) TX pulse: Number of wavelengths
#    350         4          0.0      0.0      0.0      if 'TXnow' not in param:
#    351         1          0.0      0.0      0.0          param.TXnow = 1
#    352
#    353         5          0.0      0.0      0.0      NoW = param.TXnow
#    354         5          0.0      0.0      0.0      assert np.isscalar(NoW) and utils.isnumeric(NoW) and NoW>0, 'PARAM.TXnow must be a positive scalar.'
#    355
#    356                                               #%-- 13) TX pulse: Frequency sweep for a linear chirp
#    357         4          0.0      0.0      0.0      if 'TXfreqsweep' not in param or np.isinf(NoW):
#    358         1          0.0      0.0      0.0          param.TXfreqsweep = None
#    359
#    360         5          0.0      0.0      0.0      FreqSweep = param.TXfreqsweep
#    361         5          0.0      0.0      0.0      assert FreqSweep is None or (np.isscalar(FreqSweep) and utils.isnumeric(FreqSweep) and FreqSweep>0), 'PARAM.TXfreqsweep must be empty (windowed sine) or a positive scalar (linear chirp).'
#    362
#    363                                               #%----------------------------------%
#    364                                               #% END of Check the PARAM structure %
#    365                                               #%----------------------------------%
#    366
#    367
#    368
#    369                                               #%-----------------------------%
#    370                                               #% Check the OPTIONS structure %
#    371                                               #%-----------------------------%
#    372
#    373         5          0.0      0.0      0.0      options = options.ignoreCaseInFieldNames()
#    374
#    375                                               #%-- 1) dB threshold
#    376                                               #%     (in dB: faster computation if lower value, but less accurate)
#    377         5          0.0      0.0      0.0      if 'dBThresh' not in options:
#    378                                                   options.dBThresh = -60 # default is -60dB in PFIELD
#    379
#    380         5          0.0      0.0      0.0      assert np.isscalar(options.dBThresh) and utils.isnumeric(options.dBThresh) and options.dBThresh<=0,'OPTIONS.dBThresh must be a nonpositive scalar.'
#    381
#    382                                               #%-- 2) Frequency-dependent directivity?
#    383         5          0.0      0.0      0.0      if utils.isfield(options,'FullFrequencyDirectivity'):
#    384                                                   isFFD = options.FullFrequencyDirectivity
#    385                                               else:
#    386         5          0.0      0.0      0.0          isFFD = False # % default
#    387                                                   # By default, the directivity of the elements depends on the center
#    388                                                   # frequency only. This makes the algorithm faster.
#    389
#    390         5          0.0      0.0      0.0      assert np.isscalar(isFFD) and isinstance(isFFD, bool) ,'OPTIONS.FullFrequencyDirectivity must be a logical scalar (true or false).'
#    391
#    392                                               #%-- 3) Element splitting
#    393                                               #%
#    394                                               #% --- A short note about the algorithm:
#    395                                               #% A far-field model is used in PFIELD. Each transducer element of the array
#    396                                               #% is split into M small segments, so that these M small segments are
#    397                                               #% smaller than one wavelength. The far-field condition is acceptable for
#    398                                               #% these small segments.
#    399                                               #%---
#    400         5          0.0      0.0      0.0      if utils.isfield(options,'ElementSplitting') and not options.ElementSplitting is None:
#    401                                                   M = int(options.ElementSplitting)
#    402                                                   assert np.isscalar(M) and M==np.round(M) and M>0, 'OPTIONS.ElementSplitting must be a positive integer.'
#    403                                               else:
#    404         5          0.0      0.0      0.0          LambdaMin = c/(fc*(1+param.bandwidth/200))
#    405         5          0.0      0.0      0.0          M = int(np.ceil(ElementWidth/LambdaMin))
#    406
#    407
#    408                                               #%-- 4) Wait bar
#    409         5          0.0      0.0      0.0      if not utils.isfield(options,'WaitBar'):
#    410         5          0.0      0.0      0.0          options.WaitBar = True
#    411
#    412         5          0.0      0.0      0.0      assert np.isscalar(options.WaitBar) and utils.islogical(options.WaitBar), 'OPTIONS.WaitBar must be a logical scalar (true or false).'
#    413
#    414                                               #%-- Advanced (masked) options: Frequency step (scaling factor)
#    415                                               #% The frequency step is determined automatically. It is tuned to avoid
#    416                                               #% significant interferences due to unadapted discretization. The frequency
#    417                                               #% step can also be adjusted by using a scaling factor. For a fast check,
#    418                                               #% you may use a scaling factor>1. For a smoother result, you may use a
#    419                                               #% scaling factor<1.
#    420         5          0.0      0.0      0.0      if not utils.isfield(options,'FrequencyStep'):
#    421                                                   options.FrequencyStep = 1
#    422
#    423         5          0.0      0.0      0.0      assert np.isscalar(options.FrequencyStep) and utils.isnumeric(options.FrequencyStep) and options.FrequencyStep>0, 'OPTIONS.FrequencyStep must be a positive scalar.'
#    424
#    425                                               #%------------------------------------%
#    426                                               #% END of Check the OPTIONS structure %
#    427                                               #%------------------------------------%
#    428
#    429
#    430
#    431                                               #%-----
#    432                                               #% SIMUS and MKMOVIE first run a PFIELD with empty X,Y,Z to detect possible
#    433                                               #% syntax errors.
#    434         5          0.0      0.0      0.0      if isSIMUS and len(x) == 0:
#    435                                                   return [], [], []
#    436         5          0.0      0.0      0.0      if isMKMOVIE and len(x) == 0 and not options.get('computeIndices', False):
#    437                                                   return [], [], []
#    438                                               #-----
#    439
#    440
#    441                                               #%------------------------------------%
#    442                                               #% POINT LOCATIONS, DISTANCES & GRIDS %
#    443                                               #%------------------------------------%
#    444
#    445         5          0.0      0.0      0.0      siz0 = x.shape
#    446         5          0.0      0.0      0.0      nx = np.prod(x.shape)
#    447
#    448                                               #%-- Coordinates of the points where pressure is needed
#    449         5          0.0      0.0      0.0      x = x.reshape((-1,1))
#    450         5          0.0      0.0      0.0      y = y.reshape((-1,1)) # Check if y is empty
#    451         5          0.0      0.0      0.0      z = z.reshape((-1,1))
#    452
#    453         5          0.0      0.0      0.0      if isMKMOVIE:
#    454                                                   x = np.concatenate((x, np.array(options.x).reshape((-1,1))))
#    455                                                   z = np.concatenate([z, np.array(options.z).reshape((-1,1))])
#    456                                                   #% Note with MKMOVIE:
#    457                                                   #% We must consider the points of the image grid + the points of the
#    458                                                   #% scatterers (if any). The scatterer coordinates are in options.x and
#    459                                                   #% options.z.
#    460                                                   #% Note: there is no elevation focusing with MKMOVIE (2-D only).
#    461
#    462                                               #% cast x, y, and z to single class
#    463         5          0.0      0.0      0.0      x = x.astype(np.float32)
#    464         5          0.0      0.0      0.0      y = y.astype(np.float32)
#    465         5          0.0      0.0      0.0      z = z.astype(np.float32)
#    466
#    467         5          0.0      0.0      0.0      xe, ze, THe, h = param.getElementPositions()
#    468
#    469                                               #%-- Centroids of the sub-elements
#    470                                               #%-- note: The elements have been split into M sub-elements.
#    471                                               #% X-position (xi) and Z-position (zi) of the centroids of the sub-elements
#    472                                               #% (relative to the centers of the transducer elements).
#    473                                               #% The values in xi,zi are in the range ]-ElementWidth/2 ElementWidth/2[
#    474                                               #% (if M=1, then xi = zi = 0 for a rectilinear array).
#    475         5          0.0      0.0      0.0      SegLength = ElementWidth/M
#    476         5          0.0      0.0      0.0      tmp = -ElementWidth/2 + SegLength/2 + np.arange(M)*SegLength
#    477         5          0.0      0.0      0.0      xi = tmp.reshape((1,1,M))*np.cos(THe)[:,:,np.newaxis]
#    478         5          0.0      0.0      0.0      zi = tmp.reshape((1,1,M))*np.sin(-THe)[:,:,np.newaxis]
#    479
#    480                                               #%-- Out-of-field points
#    481                                               #% Null pressure will be assigned to out-of-field points.
#    482         5          0.0      0.0      0.0      isOUT = z<0
#    483         5          0.0      0.0      0.0      if np.isfinite(RadiusOfCurvature):
#    484                                                   isOUT = np.logical_or(isOUT, (x**2+(z+h)**2) <=RadiusOfCurvature**2)
#    485
#    486                                               #%-- Variables that we need:
#    487                                               #%
#    488                                               #% Note: r = distance between the segment centroid and the point of interest
#    489                                               #%       Th = angle relative to the element normal axis.
#    490                                               #%       sinT = sine of the angle relative to the element normal axis.
#    491                                               #%       r, Th, and sinT are of size [numel(x) NumberOfElements M].
#    492                                               #%
#    493         5          0.0      0.0      0.3      dxi = x.reshape((-1,1,1))-xi-xe.reshape((1, -1, 1))
#    494         5          0.1      0.0      0.4      d2 = dxi**2+(z.reshape((-1,1,1))-zi-ze.reshape((1, -1, 1)))**2
#    495
#    496                                               #%---
#    497                                               #% we'll have 1/sqrt(r) or 1/r:
#    498                                               #% small d2 values are replaced by (lambda/4)^2
#    499         5          0.0      0.0      0.0      smallD2 = (c/fc/4)**2
#    500         5          0.0      0.0      0.0      d2[d2<smallD2] = smallD2
#    501                                               #%---
#    502         5          0.0      0.0      0.3      r = np.sqrt(d2+y.reshape((-1,1,1))**2).astype(np.float32)
#    503         5          0.1      0.0      0.8      Th = np.arcsin(dxi/np.sqrt(d2))-THe.reshape((1,-1,1))
#    504         5          0.0      0.0      0.3      sinT = np.sin(Th)
#    505                                               # clear dxi d2 Remove if needed for clear memory
#    506         5          0.0      0.0      0.0      dxi, d2 = None, None # Clear memory if needed
#    507
#    508                                               #%-------------------------------------------%
#    509                                               #% end of POINT LOCATIONS, DISTANCES & GRIDS %
#    510                                               #%-------------------------------------------%
#    511
#    512                                               #%-------------------%
#    513                                               #% FREQUENCY SPECTRA %
#    514                                               #%-------------------%
#    515
#    516                                               #GB: Same as getpulse!! Make common function
#    517
#    518                                               #%-- FREQUENCY SPECTRUM of the transmitted pulse
#    519         5          0.0      0.0      0.0      if FreqSweep is None:
#    520                                                   # We want a windowed sine of width PARAM.TXnow
#    521         5          0.0      0.0      0.0          T = NoW / fc
#    522         5          0.0      0.0      0.0          wc = 2 * np.pi * fc
#    523         5          0.0      0.0      0.0          pulseSpectrum = lambda w = None: 1j * (mysinc(T * (w - wc) / 2) - mysinc(T * (w + wc) / 2))
# ...
#    211                                               %
#    212                                               %   -- Damien Garcia -- 2017/10, last update 2022/05/14
#    213                                               %   website: <a
#    214                                               %   href="matlab:web('https://www.biomecardio.com')">www.BiomeCardio.com</a>
#    215                                               """
#    216
#    217         5          0.0      0.0      0.0      nargin = len(varargin)
#    218         5          0.0      0.0      0.0      if nargin<= 3 or nargin > 7:
#    219                                                   raise ValueError("Wrong number of input arguments.")
#    220                                               #%-- Input variables: X,Y,Z,DELAYS,PARAM,OPTIONS
#    221         5          0.0      0.0      0.0      x = varargin[0]
#    222
#    223         5          0.0      0.0      0.0      if nargin ==5: # simus(X,Z,RC,DELAYS,PARAM)
#    224                                                       y = None
#    225                                                       z = varargin[1]
#    226                                                       RC = varargin[2]
#    227                                                       delaysTX = varargin[3]
#    228                                                       param = varargin[4]
#    229                                                       options = utils.Options()
#    230         5          0.0      0.0      0.0      elif nargin == 6: # simus(X,Z,RC,DELAYS,PARAM,OPTIONS)
#    231         5          0.0      0.0      0.0              if isinstance(varargin[4], utils.Param): #% simus(X,Z,RC,DELAYS,PARAM,OPTIONS)
#    232         5          0.0      0.0      0.0                  y = None
#    233         5          0.0      0.0      0.0                  z = varargin[1]
#    234         5          0.0      0.0      0.0                  RC = varargin[2]
#    235         5          0.0      0.0      0.0                  delaysTX = varargin[3]
#    236         5          0.0      0.0      0.0                  param = varargin[4]
#    237         5          0.0      0.0      0.0                  options = copy.deepcopy(varargin[5])
#    238                                                       else: # % simus(X,Y,Z,RC,DELAYS,PARAM)
#    239                                                           y = varargin[1]
#    240                                                           z = varargin[2]
#    241                                                           RC = varargin[3]
#    242                                                           delaysTX = varargin[4]
#    243                                                           param = varargin[5]
#    244                                                           options = utils.Options()
#    245                                               else: # simus(X,Y,Z,RC,DELAYS,PARAM,OPTIONS)
#    246                                                           y = varargin[1]
#    247                                                           z = varargin[2]
#    248                                                           RC = varargin[3]
#    249                                                           delaysTX = varargin[4]
#    250                                                           param = varargin[5]
#    251                                                           options = copy.deepcopy(varargin[6])
#    252         5          0.0      0.0      0.0      assert isinstance(param, utils.Param),'PARAM must be a structure.'
#    253
#    254                                               #%-- Elevation focusing and X,Y,Z size
#    255         5          0.0      0.0      0.0      if utils.isEmpty(y):
#    256         5          0.0      0.0      0.0          ElevationFocusing = False
#    257         5          0.0      0.0      0.0          assert x.shape == z.shape and x.shape == RC.shape, 'X, Z, and RC must be of same size.'
#    258                                               else:
#    259                                                   ElevationFocusing = True
#    260                                                   assert x.shape == z.shape and x.shape == RC.shape and y.shape == x.shape,  'X, Y, Z, and RC must be of same size.'
#    261
#    262         5          0.0      0.0      0.0      if len(x.shape) ==0:
#    263                                                    return np.array([]), np.array([])
#    264
#    265
#    266                                               #%------------------------%
#    267                                               #% CHECK THE INPUT SYNTAX %
#    268                                               #%------------------------%
#    269
#    270
#    271         5          0.0      0.0      0.0      param = param.ignoreCaseInFieldNames()
#    272         5          0.0      0.0      0.0      options = options.ignoreCaseInFieldNames()
#    273         5          0.0      0.0      0.0      options.CallFun = 'simus'
#    274
#    275                                               # GB TODO: wait bar + parallelisation
#    276                                               #%-- Wait bar
#    277                                               #if ~isfield(options,'WaitBar')
#    278                                               #    options.WaitBar = true;
#    279                                               #end
#    280                                               #assert(isscalar(options.WaitBar) && islogical(options.WaitBar),...
#    281                                               #    'OPTIONS.WaitBar must be a logical scalar (true or false).')
#    282
#    283                                               #%-- Parallel pool
#    284                                               #if ~isfield(options,'ParPool')
#    285                                               #    options.ParPool = False
#    286                                               #end
#    287
#    288                                               #%-- Check if syntax errors may appear when using PFIELD
#    289                                               #try:
#    290                                               #    opt = options
#    291                                               #    opt.ParPool = false;
#    292                                               #    opt.WaitBar = false;
#    293                                               #    [~,param] = pfield([],[],delaysTX,param,opt);
#    294                                               #catch ME
#    295                                               #    throw(ME)
#    296                                               #end
#    297
#    298                                               #%-- Sampling frequency (in Hz)
#    299         4          0.0      0.0      0.0      if not utils.isfield(param,'fs'):
#    300         1          0.0      0.0      0.0          param.fs = 4*param.fc; #% default
#    301
#    302         5          0.0      0.0      0.0      assert param.fs>=4*param.fc,'PARAM.fs must be >= 4*PARAM.fc.'
#    303
#    304         5          0.0      0.0      0.0      NumberOfElements = param.Nelements # % number of array elements
#    305
#    306                                               #%-- Receive delays (in s)
#    307         4          0.0      0.0      0.0      if not utils.isfield(param,'RXdelay'):
#    308         1          0.0      0.0      0.0          param.RXdelay = np.zeros((1,NumberOfElements), dtype = np.float32)
#    309                                               else:
#    310         4          0.0      0.0      0.0          assert  isinstance(param.RXdelay, np.ndarray) and utils.isnumeric(param.RXdelay), 'PARAM.RXdelay must be a vector'
#    311         4          0.0      0.0      0.0          assert param.RXdelay.shape[1] ==NumberOfElements, 'PARAM.RXdelay must be of length = (number of elements)'
#    312         4          0.0      0.0      0.0          param.RXdelay = param.RXdelay.reshape((1,NumberOfElements))
#    313
#    314                                               #%-- dB threshold (in dB: faster computation if lower value)
#    315         5          0.0      0.0      0.0      if not utils.isfield(options,'dBThresh'):
#    316                                                   options.dBThresh = -100; # % default is -100dB in SIMUS
#    317
#    318         5          0.0      0.0      0.0      assert np.isscalar(options.dBThresh) and utils.isnumeric(options.dBThresh) and options.dBThresh<0,'OPTIONS.dBThresh must be a negative scalar.'
#    319
#    320                                               #%-- Frequency step (scaling factor)
#    321                                               #% The frequency step is determined automatically. It is tuned to avoid
#    322                                               #% aliasing in the temporal domain. The frequency step can be adjusted by
#    323                                               #% using a scaling factor. For a smoother result, you may use a scaling
#    324                                               #% factor<1.
#    325         5          0.0      0.0      0.0      if not utils.isfield(options,'FrequencyStep'):
#    326         5          0.0      0.0      0.0          options.FrequencyStep = 1
#    327
#    328         5          0.0      0.0      0.0      assert np.isscalar(options.FrequencyStep) and utils.isnumeric(options.FrequencyStep) and  options.FrequencyStep>0, 'OPTIONS.FrequencyStep must be a positive scalar.'
#    329
#    330         5          0.0      0.0      0.0      if options.FrequencyStep>1:
#    331                                                  logging.warning('MUST:FrequencyStep', 'OPTIONS.FrequencyStep is >1: aliasing may be present!')
#    332
#    333
#    334         5          0.0      0.0      0.0      RadiusOfCurvature = param.radius # % array radius-of-curvature (in m)
#    335
#    336
#    337                                               #%-------------------------------%
#    338                                              # % end of CHECK THE INPUT SYNTAX %
#    339                                              # %-------------------------------%
#    340
#    341                                               #GB NOTE: same as in pfield, put in param ?
#    342                                               #%-- Centers of the tranducer elements (x- and z-coordinates)
#    343         5          0.0      0.0      0.0      xe, ze, THe, h= param.getElementPositions()
#    344
#    345
#    346                                               #%-- Maximum distance
#    347         5          0.0      0.0      0.4      d2 = (x.reshape((-1,1))-xe)**2+(z.reshape((-1,1))-ze)**2
#    348         5          0.0      0.0      0.0      maxD = np.sqrt(np.max(d2)) #% maximum element-scatterer distance
#    349
#    350         5          0.0      0.0      0.0      maxD = maxD + np.max(delaysTX.flatten())*param.c
#    351
#    352                                               #%-- FREQUENCY SAMPLES
#    353         5          0.0      0.0      0.0      df = 1/2/(2*maxD/param.c) # % to avoid aliasing in the time domain
#    354         5          0.0      0.0      0.0      df = df*options.FrequencyStep
#    355         5          0.0      0.0      0.0      Nf = 2*int(np.ceil(param.fc/df))+1 # % number of frequency samples
#    356
#    357                                               #%-- Run PFIELD to calculate the RF spectra
#    358         5          0.0      0.0      0.0      RFspectrum = np.zeros((Nf,NumberOfElements), dtype = np.complex64)# % will contain the RF spectra
#    359         5          0.0      0.0      0.0      options.FrequencyStep = df
#    360
#    361                                               #%- run PFIELD in a parallel pool (NW workers)
#    362         5          0.0      0.0      0.0      if options.get('ParPool', False):
#    363
#    364                                                   with options.getParallelPool() as pool:
#    365                                                       idx = options.getParallelSplitIndices(x.shape[1])
#    366
#    367                                                       RS = pool.starmap(functools.partial(pfieldParallel, delaysTX = delaysTX, param = param, options = options),
#    368                                                                       [ ( x[:,i:j],
#    369                                                                           y[:,i:j] if not utils.isEmpty(y) else None,
#    370                                                                           z[:,i:j],
#    371                                                                           RC[:,i:j]) for i,j in idx ])
#    372
#    373
#    374                                                       for (RFsp, idx_spectrum) in RS:
#    375                                                           RFspectrum[idx_spectrum, :] += RFsp
#    376
#    377                                               #    end
#    378                                               else:
#    379                                                   #%- no parallel pool
#    380         5          0.0      0.0      0.0          options.RC =  RC
#    381         5         12.4      2.5     99.4          _, RFsp,idx = pfield(x,y,z,delaysTX,param,options)
#    382         5          0.0      0.0      0.0          RFspectrum[idx,:]  = RFsp
#    383
#    384                                               #%-- RF signals (in the time domain)
#    385         5          0.0      0.0      0.0      nf = int(np.ceil(param.fs/2/param.fc*(Nf-1)))
#    386         5          0.0      0.0      0.1      RF = np.fft.irfft(np.conj(RFspectrum),nf, axis = 0)
#    387         5          0.0      0.0      0.0      RF = RF[:nf//2]*param.fs/4/param.fc
#    388
#    389                                               #%-- Zeroing the very small values
#    390         5          0.0      0.0      0.0      RelThresh = 1e-5#; % -100 dB
#    391         5          0.0      0.0      0.0      tmp2= lambda RelRF: 0.5*(1+np.tanh((RelRF-RelThresh)/(RelThresh/10)))
#    392         5          0.0      0.0      0.0      tmp = lambda RelRF: np.round(tmp2(RelRF)/(RelThresh/10))*(RelThresh/10)
#    393         5          0.0      0.0      0.0      RF = RF*tmp(np.abs(RF)/np.max(np.abs(RF)))
#    394
#    395         5          0.0      0.0      0.0      return RF,RFspectrum

# %%
x,z = pymust.impolgrid(np.array([256, 256]),
                          10e-2, 
                          np.pi/3,
                          param)
Mdas = pymust.dasmtx(IQ[:,:,0],x,z,param)
IQb = np.zeros((x.shape[0], x.shape[1], nreps), dtype = np.complex128)
for i in tqdm.notebook.tqdm(range(nreps)):
    IQb[:, :, i] = (Mdas@IQ[:,:,i].flatten(order = 'F')).reshape(x.shape, order = 'F')
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
b = pymust.bmode(IQb[:,:,0])
fig = plt.figure(figsize=[5,5])
ax = fig.add_axes([0.15,0.15,0.8,0.8])
#fig.set_facecolor("black")
ax.pcolormesh(z, x , b,edgecolors='face', cmap = 'gray')
ax.set_facecolor('black')
#ec='face' to avoid annoying gridding in pdf
plt.savefig('carte_polar.png')
# Out:
# /var/folders/s4/bzy_db252n15287qgjz2gfzh0000gn/T/ipykernel_7535/2099971117.py:5: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   ax.pcolormesh(z, x , b,edgecolors='face', cmap = 'gray')

# %%
doppler_vel, doppler_var = pymust.iq2doppler(IQb,param)
VN = pymust.getNyquistVelocity(param)

# %%
#fig = plt.figure(figsize=[5,5])
#ax = fig.add_axes([0.15,0.15,0.8,0.8])
#fig.set_facecolor("black")
plt.pcolormesh(z, x , b,edgecolors='face', cmap = 'gray')
plt.axis('equal')

cm = plt.pcolormesh(z, x , doppler_vel,edgecolors='face', cmap = pymust.getDopplerColorMap().cmap, alpha = doppler_var/np.max(doppler_var), vmin = -VN, vmax = VN)
ax.set_facecolor('black')
#ec='face' to avoid annoying gridding in pdf
cbar = plt.colorbar(cm)
cbar.ax.set_ylabel('Velocity [m/s]')
ax = plt.gca()
ax.set_facecolor('black')

plt.savefig('carte_polar.png')
# Out:
# /var/folders/s4/bzy_db252n15287qgjz2gfzh0000gn/T/ipykernel_7535/998413440.py:4: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   plt.pcolormesh(z, x , b,edgecolors='face', cmap = 'gray')
# /var/folders/s4/bzy_db252n15287qgjz2gfzh0000gn/T/ipykernel_7535/998413440.py:7: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   cm = plt.pcolormesh(z, x , doppler_vel,edgecolors='face', cmap = pymust.getDopplerColorMap().cmap, alpha = doppler_var/np.max(doppler_var), vmin = -VN, vmax = VN)

# %%
fig = plt.figure(figsize=[5,5])
ax = fig.add_axes([0.15,0.15,0.8,0.8])
#fig.set_facecolor("black")
ax.pcolormesh(z, x , b,edgecolors='face', cmap = 'gray')

cm = ax.pcolormesh(z, x , doppler_var,edgecolors='face', cmap = pymust.getDopplerColorMap().cmap, )
ax.set_facecolor('black')
#ec='face' to avoid annoying gridding in pdf
cbar = plt.colorbar(cm)
cbar.ax.set_ylabel('Variance')
plt.title('Doppler variance')
#plt.savefig('carte_polar.png')
# Out:
# /var/folders/s4/bzy_db252n15287qgjz2gfzh0000gn/T/ipykernel_7535/4283511898.py:4: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   ax.pcolormesh(z, x , b,edgecolors='face', cmap = 'gray')
# /var/folders/s4/bzy_db252n15287qgjz2gfzh0000gn/T/ipykernel_7535/4283511898.py:6: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   cm = ax.pcolormesh(z, x , doppler_var,edgecolors='face', cmap = pymust.getDopplerColorMap().cmap, )
# Text(0.5, 1.0, 'Doppler variance')
